# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/Projects/Flight price prediction - 3"
# !python -m app
# Out:
# /content/drive/MyDrive/Colab Notebooks/Projects/Flight price prediction - 3
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://6507-35-234-15-246.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [26/Aug/2021 09:26:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Aug/2021 09:26:31] "GET /static/scripts.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Aug/2021 09:26:31] "GET /static/styles.css HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Aug/2021 09:26:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Aug/2021 09:26:32] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [26/Aug/2021 09:26:34] "GET /static/scripts.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Aug/2021 09:26:34] "GET /static/styles.css HTTP/1.1" 200 -
# ...

# %%
pip install flask-ngrok
